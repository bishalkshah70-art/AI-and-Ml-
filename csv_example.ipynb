# %% [markdown]
# <a href="https://colab.research.google.com/github/bishalkshah70-art/AI-and-Ml-/blob/main/csv_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report, accuracy_score

# %%
print("Step 1: Ingesting dataset infcrastructure...")
df = pd.read_csv("/content/customer_churn_ann_dataset1_55d8b8a8-aa58-4c01-b459-d30aeda770d2_268917_.csv")

df = df.drop(columns=['CustomerID'])
# Out:
# Step 1: Ingesting dataset infcrastructure...

# %%
#handle missing data using a safe indicator value]
df['Internetservices']= df['InternetService'].fillna('Unknown')

# %%
x_raw = df.drop(columns=['Churn'])
y = f
